# %%
# Import necessary packages
import os 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define working directory
os.chdir('C:\\Users\\ysfno1\\Desktop\Data')

# %%
# Load datasets
df1 = pd.read_csv('Stress_Labeled.csv',encoding="unicode_escape")
df2 = pd.read_csv('Trauma_Labeled.csv',encoding="unicode_escape")
df3 = pd.read_csv('Anxiety_Labeled.csv',encoding="unicode_escape")
df4 = pd.read_csv('The Baghdad Clock.csv',encoding="unicode_escape")
df5 = pd.read_csv('Baghdad Diaries 1991-2002.csv',encoding="unicode_escape")
df6 = pd.read_csv('The beekeeper of aleppo.csv',encoding="unicode_escape")
df7 = pd.read_csv('The girl from aleppo.csv',encoding="unicode_escape")
df8 = pd.read_csv('The orange trees of bagdad.csv',encoding="unicode_escape")
df9 = pd.read_csv('Barefoot in bagdad.csv',encoding="unicode_escape")
df10 = pd.read_csv('Escape from aleppo.csv',encoding="unicode_escape")
df11 = pd.read_csv('Shooting Kabul.csv',encoding="unicode_escape")
df12 = pd.read_csv('The boy from aleppo.csv',encoding="unicode_escape")
df13 = pd.read_csv('Diaries of the syrian revolution.csv',encoding="unicode_escape")

# %% [markdown]
# ### Sentiment-Stress

# %%
# Check frequent words
from wordcloud import WordCloud
text1 = " ".join(Sentence for Sentence in df1.Sentence)
word_cloud1 = WordCloud(collocations = False, background_color = 'white').generate(text1)
plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Sentiment-Trauma

# %%
# Check frequent words
from wordcloud import WordCloud
text2 = " ".join(Sentence for Sentence in df2.Sentence)
word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(text2)
plt.imshow(word_cloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Sentiment-Anxiety

# %%
# Check frequent words
from wordcloud import WordCloud
text3 = " ".join(Sentence for Sentence in df3.Sentence)
word_cloud3 = WordCloud(collocations = False, background_color = 'white').generate(text3)
plt.imshow(word_cloud3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### The Baghdad Clock - al Rawi, Shahad

# %%
# Check frequent words
from wordcloud import WordCloud
text4 = " ".join(Sentence for Sentence in df4.keyword)
word_cloud4 = WordCloud(collocations = False, background_color = 'white').generate(text4)
plt.imshow(word_cloud4, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df4.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Baghdad Diaries 1991-2002 - al Rawi, Shahad

# %%
# Check frequent words
from wordcloud import WordCloud
text5 = " ".join(Sentence for Sentence in df5.keyword)
word_cloud5 = WordCloud(collocations = False, background_color = 'white').generate(text5)
plt.imshow(word_cloud5, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df5.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### The Beekeeper of Aleppo - Lefteri, Christy

# %%
# Check frequent words
from wordcloud import WordCloud
text6 = " ".join(Sentence for Sentence in df6.keyword)
word_cloud6 = WordCloud(collocations = False, background_color = 'white').generate(text6)
plt.imshow(word_cloud6, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df6.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### The Girl from Aleppo - Mustafa, Nujeen

# %%
# Check frequent words
from wordcloud import WordCloud
text7 = " ".join(Sentence for Sentence in df7.keyword)
word_cloud7 = WordCloud(collocations = False, background_color = 'white').generate(text7)
plt.imshow(word_cloud7, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df7.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### The Orange Trees of Baghdad - Nadir, Leilah

# %%
# Check frequent words
from wordcloud import WordCloud
text8 = " ".join(Sentence for Sentence in df8.keyword)
word_cloud8 = WordCloud(collocations = False, background_color = 'white').generate(text8)
plt.imshow(word_cloud8, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df8.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Barefoot in Baghdad - Omar, Manal M

# %%
# Check frequent words
from wordcloud import WordCloud
text9 = " ".join(Sentence for Sentence in df9.keyword)
word_cloud9 = WordCloud(collocations = False, background_color = 'white').generate(text9)
plt.imshow(word_cloud9, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df9.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Escape from Aleppo - Senzai, N H

# %%
# Check frequent words
from wordcloud import WordCloud
text10 = " ".join(Sentence for Sentence in df10.keyword)
word_cloud10 = WordCloud(collocations = False, background_color = 'white').generate(text10)
plt.imshow(word_cloud10, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df10.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Shooting Kabul - Senzai, N H

# %%
# Check frequent words
from wordcloud import WordCloud
text11 = " ".join(Sentence for Sentence in df11.keyword)
word_cloud11 = WordCloud(collocations = False, background_color = 'white').generate(text11)
plt.imshow(word_cloud11, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df11.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### The Boy from Aleppo - Sukkar, Sumia

# %%
# Check frequent words
from wordcloud import WordCloud
text12 = " ".join(Sentence for Sentence in df12.keyword)
word_cloud12 = WordCloud(collocations = False, background_color = 'white').generate(text11)
plt.imshow(word_cloud12, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df12.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Diaries of the Syrian Revolution - Yazbek, Samar

# %%
# Check frequent words
from wordcloud import WordCloud
text13 = " ".join(Sentence for Sentence in df13.keyword)
word_cloud13 = WordCloud(collocations = False, background_color = 'white').generate(text11)
plt.imshow(word_cloud13, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Check sentiments distribution
import seaborn as sns
import matplotlib.pyplot as plt
x=df13.Label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('Count')
# Out:
# E:\DS\Conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')
